# %%
pip install pandas matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd
import matplotlib.pyplot as plt

# قراءة البيانات من ملف CSV
df = pd.read_csv(r"D:\مهام اضافية\Patients Data\patients_data.csv")

# عرض أول 5 صفوف
print("🔍 First 5 Patients:\n", df.head())

# عدد المرضى الإجمالي
print("\n👥 Total Patients:", len(df))

# إحصائيات عن الأعمار
print("\n📊 Age Statistics:\n", df['Age'].describe())

# توزيع الأمراض
disease_counts = df['Disease'].value_counts()
print("\n🦠 Disease Distribution:\n", disease_counts)

# توزيع النتائج (Outcome)
outcome_counts = df['Outcome'].value_counts()
print("\n📈 Outcome Distribution:\n", outcome_counts)

# توزيع العلاجات
treatment_counts = df['Treatment'].value_counts()
print("\n💊 Treatment Types:\n", treatment_counts)

# رسم بياني للأمراض
plt.figure(figsize=(8, 5))
disease_counts.plot(kind='bar', color='skyblue', title='Disease Distribution')
plt.xlabel('Disease')
plt.ylabel('Number of Patients')
plt.tight_layout()
plt.show()

# رسم بياني للنتائج
plt.figure(figsize=(6, 6))
outcome_counts.plot(kind='pie', autopct='%1.1f%%', startangle=140, title='Patient Outcomes')
plt.ylabel('')
plt.tight_layout()
plt.show()

# رسم بياني للعلاجات
plt.figure(figsize=(8, 5))
treatment_counts.plot(kind='barh', color='lightgreen', title='Treatment Types')
plt.xlabel('Number of Patients')
plt.ylabel('Treatment')
plt.tight_layout()
plt.show()
# Out:
# 🔍 First 5 Patients:
#     PatientID     Name  Age  Gender        Disease AdmissionDate DischargeDate  \
# 0          1    Ahmed   45    Male       Diabetes    2023-01-01    2023-01-10
# 1          2    Salma   60  Female   Hypertension    2023-02-15    2023-02-25
# 2          3  Youssef   30    Male       COVID-19    2023-03-10    2023-03-20
# 3          4     Mona   25  Female            Flu    2023-04-01    2023-04-05
# 4          5    Tamer   55    Male  Heart Disease    2023-05-01    2023-05-12
#
#      Outcome       Treatment FollowUpDate
# 0  Recovered         Insulin   2023-02-10
# 1  Recovered   Beta Blockers   2023-03-30
# 2   Deceased  Oxygen Therapy   2023-04-20
# 3  Recovered   Rest & Fluids   2023-04-25
# 4  Recovered         Statins   2023-06-15
#
# 👥 Total Patients: 12
#
# 📊 Age Statistics:
#  count    12.000000
# mean     40.833333
# std      14.262687
# min      22.000000
# 25%      29.500000
# 50%      38.500000
# 75%      51.250000
# max      65.000000
# ...
